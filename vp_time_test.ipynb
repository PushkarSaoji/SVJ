# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import*

# %%
col_names= ["N", "tree_t", "search_t"]

data= pd.read_csv("SIFT/tree_time.csv", names= col_names)

# %%
x= data["N"]
y1=data["tree_t"]
y2=data["search_t"]

# %%
data
# Out:
#        N  tree_t  search_t
# 0    398     200      4896
# 1    446     179      6160
# 2    390     157      4820
# 3    526     218      8571
# 4    266     119      2166
# ..   ...     ...       ...
# 995  174      67       939
# 996  243      92      1795
# 997  335     134      3472
# 998  637     269     12671
# 999  495     200      7579
#
# [1000 rows x 3 columns]

# %%
a1, b1 = np.polyfit(x, y1, 1)
y_fit1= a1*x + b1

# %%
a2, b2 = np.polyfit(x, y2, 1)
y_fit2= a2*x + b2

# %%
plt.scatter(x, y1)
plt.plot(x, y_fit1, label=f"Fit: y =  {a1:.2f}x + {b1:.2f}", color="blue")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("poly Fit")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
plt.scatter(x, y2)
plt.plot(x, y_fit2, label=f"Fit: y =  {a2:.2f}x + {b2:.2f}", color="blue")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("poly Fit")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
x_log= np.log10(x)
x2= np.square(x)

# %%
a3, b3 = np.polyfit(x2, y2, 1)
y_fit3= a3*x2 + b3

# %%
plt.scatter(x2, y2)
plt.plot(x2, y_fit3, label=f"Fit: y =  {a3:.2f}x + {b3:.2f}", color="blue")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("poly Fit")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
